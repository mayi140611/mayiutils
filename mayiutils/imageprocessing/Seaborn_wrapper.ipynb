# %% [markdown]
# ### http://seaborn.pydata.org/tutorial.html

# %%
# %load seaborn_wrapper.py
#!/usr/bin/python

"""
@author: Ian
@file: seaborn_wrapper.py
@time: 2019-04-26 10:17
"""
import seaborn as sns
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g = sb.pairplot(iris)

# %%
g = sb.pairplot(iris, hue="species")

# %%
g = sb.pairplot(iris, hue="species", palette="husl")

# %%
g = sb.pairplot(iris, hue="species", markers=["o", "s", "D"])

# %%
g = sb.pairplot(iris, vars=["sepal_width", "sepal_length"])

# %% [markdown]
# ### Draw larger plots:

# %%
g = sb.pairplot(iris, height=3,
                         vars=["sepal_width", "sepal_length"])

# %%
g = sb.pairplot(iris,
                          x_vars=["sepal_width", "sepal_length"],
                      y_vars=["petal_width", "petal_length"])

# %%
g = sb.pairplot(iris, diag_kind="kde")

# %% [markdown]
# ### Fit linear regression models to the scatter plots:

# %%
g = sb.pairplot(iris, kind="reg")

# %% [markdown]
# ### Pass keyword arguments down to the underlying functions (it may be easier to use :class:`PairGrid` directly):

# %%
g = sb.pairplot(iris, diag_kind="kde", markers="+",
                          plot_kws=dict(s=50, edgecolor="b", linewidth=1),
                          diag_kws=dict(shade=True))

# %%
plt.figure(figsize=(10, 10))
for i, col in enumerate(iris.columns[:-1]):
    plt.subplot(2, 2, i+1)
    sb.violinplot(x='species', y=col, data=iris)

# %%
uniform_data = np.random.rand(10, 12)
uniform_data
# Out:
# array([[7.82366705e-01, 4.36827723e-01, 1.11306486e-01, 8.24685940e-02,
#         3.40220780e-01, 1.86180175e-01, 5.99156869e-01, 4.90751299e-01,
#         7.41576635e-01, 5.07772423e-01, 6.76962718e-01, 2.84674370e-01],
#        [1.58347996e-01, 9.83226833e-02, 9.71751349e-01, 8.17182423e-01,
#         2.24946607e-01, 7.71945037e-01, 5.52376189e-01, 8.37938026e-01,
#         7.93012897e-01, 6.40683015e-01, 1.97109702e-01, 8.96217002e-01],
#        [7.20353799e-01, 2.64739745e-01, 6.24161990e-01, 2.47829463e-01,
#         1.62447226e-01, 8.36594579e-01, 7.34936850e-01, 9.96753526e-01,
#         7.62204885e-01, 2.22610860e-01, 3.87261878e-01, 8.86501716e-01],
#        [7.76647616e-02, 8.82972295e-01, 5.52474017e-01, 9.46572340e-02,
#         7.68301833e-01, 4.38836973e-01, 9.87400806e-01, 7.94457138e-01,
#         7.28201925e-02, 3.33016996e-01, 6.64749735e-01, 5.45277420e-01],
#        [1.28349527e-01, 2.43204896e-01, 6.63287902e-01, 8.98808533e-01,
#         9.66440549e-01, 3.41213108e-01, 8.89754147e-01, 3.28675603e-01,
#         8.18751174e-01, 8.28736146e-01, 9.26682496e-01, 3.82602046e-01],
#        [8.74697245e-01, 4.29244285e-01, 7.40074452e-04, 7.91814478e-01,
#         9.22483286e-01, 1.69076890e-01, 3.27126641e-01, 5.35384907e-01,
#         9.67449476e-02, 1.14920720e-01, 8.30146145e-01, 7.60661589e-01],
#        [4.54247341e-01, 2.58960953e-01, 4.13785331e-01, 9.39506500e-01,
#         5.72863082e-01, 8.06422200e-01, 9.24362185e-01, 7.99450856e-01,
#         2.65402536e-01, 2.73871094e-01, 5.54053519e-01, 1.87812045e-01],
#        [6.57786420e-01, 7.39058866e-01, 1.35399167e-01, 8.90481907e-02,
#         1.16053478e-01, 3.96438023e-01, 1.34539224e-01, 9.45505820e-01,
#         4.91245338e-01, 6.52062272e-01, 6.13324588e-01, 1.52802536e-01],
#        [9.63677978e-01, 8.84826448e-01, 5.85784488e-01, 4.58858590e-01,
#         1.00150694e-01, 2.77704749e-01, 1.37937735e-01, 3.89683933e-01,
#         8.65671458e-01, 3.82185166e-01, 9.21205616e-01, 8.56000054e-01],
#        [6.41040653e-01, 1.61849546e-01, 9.56682836e-01, 5.08970622e-01,
#         7.56063594e-01, 7.37272929e-01, 4.39693553e-01, 6.63357221e-03,
#         8.84370416e-01, 2.72073118e-01, 7.43048263e-02, 9.60881296e-01]])

# %%
ax = sb.heatmap(uniform_data)

# %%
cmap : matplotlib colormap name or object, or list of colors, optional
    The mapping from data values to color space. If not provided, the
    default will depend on whether ``center`` is set.

# %%
ax = sb.heatmap(uniform_data, cmap='Blues')
